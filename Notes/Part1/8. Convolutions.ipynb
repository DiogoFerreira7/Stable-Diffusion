# %%
# !pip install torch
# Out:
# ...
#      ---------------------------------------- 0.0/172.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/172.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/172.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/172.3 MB ? eta -:--:--
#      -------------------------------------- 0.0/172.3 MB 186.2 kB/s eta 0:15:26
#      -------------------------------------- 0.0/172.3 MB 186.2 kB/s eta 0:15:26
#      -------------------------------------- 0.0/172.3 MB 186.2 kB/s eta 0:15:26
#      -------------------------------------- 0.0/172.3 MB 186.2 kB/s eta 0:15:26
#      -------------------------------------- 0.0/172.3 MB 186.2 kB/s eta 0:15:26
#      -------------------------------------- 0.0/172.3 MB 186.2 kB/s eta 0:15:26
#      -------------------------------------- 0.0/172.3 MB 186.2 kB/s eta 0:15:26
#      -------------------------------------- 0.0/172.3 MB 186.2 kB/s eta 0:15:26
# ...

# %%
import torch.nn as nn

# %%
class T(Module):
    def __init__(self):
        self.a = nn.Parameter(torch.ones(3))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 class T(Module):
#       2     def __init__(self):
#       3         self.a = nn.Parameter(torch.ones(3))
#
# NameError: name 'Module' is not defined

# %%
print("hello")
